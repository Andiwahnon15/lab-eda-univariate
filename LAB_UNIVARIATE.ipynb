# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\andre\Downloads\Murder\LAB\amz_uk_price_prediction_dataset.csv')

# %%
df.head()
# Out:
#    uid        asin                                              title  stars  \
# 0    1  B09B96TG33  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 1    2  B01HTH3C8S  Anker Soundcore mini, Super-Portable Bluetooth...    4.7
# 2    3  B09B8YWXDF  Echo Dot (5th generation, 2022 release) | Big ...    4.7
# 3    4  B09B8T5VGV  Echo Dot with clock (5th generation, 2022 rele...    4.7
# 4    5  B09WX6QD65  Introducing Echo Pop | Full sound compact Wi-F...    4.6
#
#    reviews  price  isBestSeller  boughtInLastMonth        category
# 0    15308  21.99         False                  0  Hi-Fi Speakers
# 1    98099  23.99          True                  0  Hi-Fi Speakers
# 2    15308  21.99         False                  0  Hi-Fi Speakers
# 3     7205  31.99         False                  0  Hi-Fi Speakers
# 4     1881  17.99         False                  0  Hi-Fi Speakers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2443651 entries, 0 to 2443650
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   uid                int64
#  1   asin               object
#  2   title              object
#  3   stars              float64
#  4   reviews            int64
#  5   price              float64
#  6   isBestSeller       bool
#  7   boughtInLastMonth  int64
#  8   category           object
# dtypes: bool(1), float64(2), int64(3), object(3)
# memory usage: 151.5+ MB

# %%
# PARTE 1
# Generar una tabla de frecuencia para la categoría del producto
frequency_table = df['category'].value_counts()
print(frequency_table.head(5))
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
# Gráfico de barras para la distribución de productos en diferentes categorías
top_categories = frequency_table.head(10)  # Tomando las 10 categorías más comunes como ejemplo
plt.figure(figsize=(12, 6))
sns.barplot(x=top_categories.index, y=top_categories.values)
plt.xticks(rotation=45)
plt.title('Distribución de Productos en Categorías Principales')
plt.xlabel('Categoría')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Gráfico circular para las proporciones de las categorías principales
plt.pie(top_categories, labels=top_categories.index, autopct='%1.1f%%')
plt.title('Proporciones de Productos en Categorías Principales')
plt.show()

# %%
# PARTE 2
# Calcular la media, la mediana y la moda para el precio de los productos
mean_price = df['price'].mean()
median_price = df['price'].median()
mode_price = df['price'].mode()

print(f"Media de precios: {mean_price}, Mediana de precios: {median_price}, Moda de precios: {mode_price}")
# Out:
# Media de precios: 89.24380943923663, Mediana de precios: 19.09, Moda de precios: 0    9.99
# Name: price, dtype: float64

# %%
# Calcular la varianza, la desviación estándar, el rango y el rango intercuartílico para el precio de los productos
variance_price = df['price'].var()
std_dev_price = df['price'].std()
price_range = df['price'].max() - df['price'].min()
price_iqr = df['price'].quantile(0.75) - df['price'].quantile(0.25)

print(f"Varianza de precios: {variance_price}, Desviación estándar de precios: {std_dev_price}, Rango de precios: {price_range}, Rango intercuartílico de precios: {price_iqr}")
# Out:
# Varianza de precios: 119445.48532256528, Desviación estándar de precios: 345.60886175352226, Rango de precios: 100000.0, Rango intercuartílico de precios: 36.0

# %%
# Histograma para la distribución de precios de productos
plt.hist(df['price'].head(20), bins='auto')
plt.xlabel('Precio')
plt.ylabel('Frecuencia')
plt.title('Distribución de Precios de Productos')
plt.show()

# %%
# Box plot para visualizar la distribución de precios de productos
plt.boxplot(df['price'])
plt.ylabel('Precio')
plt.title('Boxplot de Precios de Productos')
plt.show()

# %%
# PARTE 3 
# Calcular la media, la mediana y la moda para la calificación de los productos
mean_rating = df['stars'].mean()
median_rating = df['stars'].median()
mode_rating = df['stars'].mode()
print(f"Media de calificaciones: {mean_rating}, Mediana de calificaciones: {median_rating}, Moda de calificaciones: {mode_rating}")
# Out:
# Media de calificaciones: 2.152836472966065, Mediana de calificaciones: 0.0, Moda de calificaciones: 0    0.0
# Name: stars, dtype: float64

# %%
# Calcular la varianza, la desviación estándar y el rango intercuartílico para las calificaciones de los productos
variance_rating = df['stars'].var()
std_dev_rating = df['stars'].std()
iqr_rating = df['stars'].quantile(0.75) - df['stars'].quantile(0.25)
print(f"Varianza de calificaciones: {variance_rating}, Desviación estándar de calificaciones: {std_dev_rating}, Rango intercuartílico de calificaciones: {iqr_rating}")
# Out:
# Varianza de calificaciones: 4.81743402976196, Desviación estándar de calificaciones: 2.1948653785054697, Rango intercuartílico de calificaciones: 4.4

# %%
# Calcular el sesgo y la curtosis para las calificaciones de los productos
skewness_rating = df['stars'].skew()
kurtosis_rating = df['stars'].kurt()
print(f"Sesgo de calificaciones: {skewness_rating}, Curtosis de calificaciones: {kurtosis_rating}")
# Out:
# Sesgo de calificaciones: 0.08120735761080985, Curtosis de calificaciones: -1.9260061280432985

# %%
# Histograma para la distribución de calificaciones de productos
plt.hist(df['stars'], bins='auto')
plt.xlabel('Calificación')
plt.ylabel('Frecuencia')
plt.title('Distribución de Calificaciones de Productos')
plt.show()
